# %%
import  yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple = yf.download("AAPL", start = "2010-01-01", end = "2021-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Apple
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2010-01-04    6.406480    6.421148    6.357685    6.389117  493729600
# 2010-01-05    6.417556    6.453778    6.383729    6.424142  601904800
# 2010-01-06    6.315477    6.443002    6.308891    6.417557  552160000
# 2010-01-07    6.303801    6.346310    6.258000    6.338826  477131200
# 2010-01-08    6.345710    6.346309    6.258299    6.295418  447610800
# ...                ...         ...         ...         ...        ...
# 2020-12-24  128.228287  129.676046  127.382958  127.596722   54930100
# 2020-12-28  132.814453  133.446018  129.724607  130.191009  124486200
# 2020-12-29  131.046066  134.854922  130.531094  134.135912  121047300
# 2020-12-30  129.928680  132.134324  129.617746  131.735945   96452100
# 2020-12-31  128.927872  130.919751  127.985373  130.278461   99116600
#
# [2769 rows x 5 columns]

# %%
ticker=["SPY","AAPL","KO"]

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2021-01-01")
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
stocks
# Out:
# Price            Close                               High             \
# Ticker            AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.406480  17.316336   84.796379    6.421148  17.370981
# 2010-01-05    6.417556  17.106859   85.020851    6.453778  17.301153
# 2010-01-06    6.315477  17.100784   85.080719    6.443002  17.134177
# 2010-01-07    6.303801  17.058292   85.439857    6.346310  17.112937
# 2010-01-08    6.345710  16.742567   85.724182    6.346309  16.891322
# ...                ...        ...         ...         ...        ...
# 2020-12-24  128.228287  45.663017  343.514618  129.676046  45.757010
# 2020-12-28  132.814453  46.278240  346.465668  133.446018  46.517492
# 2020-12-29  131.046066  46.252602  345.804749  134.854922  46.560212
# 2020-12-30  129.928680  46.517490  346.298126  132.134324  46.679842
# 2020-12-31  128.927872  46.859280  348.057587  130.919751  46.936182
#
# Price                          Low                               Open  \
# Ticker             SPY        AAPL         KO         SPY        AAPL
# Date
# 2010-01-04   84.841271    6.357685  17.273834   83.434609    6.389117
# 2010-01-05   85.058265    6.383729  17.043107   84.437236    6.424142
# 2010-01-06   85.290221    6.308891  16.994530   84.871217    6.417557
# 2010-01-07   85.544609    6.258000  16.924717   84.684148    6.338826
# 2010-01-08   85.761596    6.258299  16.621134   85.043300    6.295418
# ...                ...         ...        ...         ...         ...
# 2020-12-24  343.542545  127.382958  45.304140  342.071682  127.596722
# 2020-12-28  346.856644  129.724607  45.910817  345.441635  130.191009
# 2020-12-29  348.169329  130.531094  46.158609  345.218256  134.135912
# 2020-12-30  347.331478  129.617746  46.167157  345.907150  131.735945
# 2020-12-31  348.783714  127.985373  46.372230  345.590617  130.278461
#
# Price                                 Volume
# Ticker             KO         SPY       AAPL        KO        SPY
# Date
# 2010-01-04  17.352765   84.078083  493729600  13870400  118944600
# 2010-01-05  17.258650   84.744011  601904800  23172400  111579900
# 2010-01-06  17.106855   84.938554  552160000  19264600  116074400
# 2010-01-07  17.100795   84.923580  477131200  13234600  131091100
# 2010-01-08  16.836677   85.215389  447610800  28712400  126402800
# ...               ...         ...        ...       ...        ...
# 2020-12-24  45.304140  342.658146   54930100   3265500   26457900
# 2020-12-28  46.013352  346.065345  124486200   9020500   39000400
# 2020-12-29  46.526033  347.992449  121047300   8320600   53680500
# 2020-12-30  46.184247  346.623959   96452100   8142700   49455300
# 2020-12-31  46.526036  346.102620   99116600   8495000   78520700
#
# [2769 rows x 15 columns]

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2769 entries, 2010-01-04 to 2020-12-31
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   2769 non-null   float64
#  1   (Close, KO)     2769 non-null   float64
#  2   (Close, SPY)    2769 non-null   float64
#  3   (High, AAPL)    2769 non-null   float64
#  4   (High, KO)      2769 non-null   float64
#  5   (High, SPY)     2769 non-null   float64
#  6   (Low, AAPL)     2769 non-null   float64
#  7   (Low, KO)       2769 non-null   float64
#  8   (Low, SPY)      2769 non-null   float64
#  9   (Open, AAPL)    2769 non-null   float64
#  10  (Open, KO)      2769 non-null   float64
#  11  (Open, SPY)     2769 non-null   float64
#  12  (Volume, AAPL)  2769 non-null   int64
#  13  (Volume, KO)    2769 non-null   int64
#  14  (Volume, SPY)   2769 non-null   int64
# dtypes: float64(12), int64(3)
# memory usage: 346.1 KB

# %%
stocks.to_csv("stocksYT.csv")

# %%
stocks = pd.read_csv("stocksYT.csv")

# %%
stocks
# Out:
#            Price               Close             Close.1             Close.2  \
# 0         Ticker                AAPL                  KO                 SPY
# 1           Date                 NaN                 NaN                 NaN
# 2     2010-01-04   6.406479835510254  17.316335678100586   84.79637908935547
# 3     2010-01-05   6.417556285858154   17.10685920715332    85.0208511352539
# 4     2010-01-06   6.315476894378662  17.100784301757812   85.08071899414062
# ...          ...                 ...                 ...                 ...
# 2766  2020-12-24  128.22828674316406   45.66301727294922   343.5146179199219
# 2767  2020-12-28       132.814453125   46.27824020385742   346.4656677246094
# 2768  2020-12-29   131.0460662841797  46.252601623535156  345.80474853515625
# 2769  2020-12-30  129.92868041992188   46.51749038696289   346.2981262207031
# 2770  2020-12-31  128.92787170410156   46.85927963256836   348.0575866699219
#
#                     High              High.1              High.2  \
# 0                   AAPL                  KO                 SPY
# 1                    NaN                 NaN                 NaN
# 2      6.421148128853102  17.370980587927995   84.84127078300016
# 3      6.453778177942326  17.301152818605626   85.05826468909152
# 4      6.443001926272175  17.134177367889965   85.29022121603725
# ...                  ...                 ...                 ...
# 2766  129.67604646021374  45.757009786040484    343.542544801245
# 2767  133.44601785068772  46.517491511124675   346.8566440369137
# 2768  134.85492191166836   46.56021227356761   348.1693289377811
# 2769  132.13432398091498   46.67984227830328  347.33147772383484
# 2770  130.91975146585497   46.93618230042677  348.78371400805713
#
#                      Low               Low.1               Low.2  \
# 0                   AAPL                  KO                 SPY
# 1                    NaN                 NaN                 NaN
# 2      6.357685178167795  17.273834338918075   83.43460919990564
# 3      6.383728882783618  17.043107213027632   84.43723622983082
# 4      6.308890950123877  16.994529846731247   84.87121677224401
# ...                  ...                 ...                 ...
# 2766  127.38295839338778   45.30414032429653   342.0716817018129
# 2767  129.72460743607215   45.91081669080865   345.4416347950201
# 2768   130.5310944025397  46.158609118296994   345.2182555477863
# 2769   129.6177461619134  46.167156727121615  345.90714985399984
# 2770   127.9853727167279   46.37223048931656  345.59061740637577
#
#                     Open              Open.1              Open.2     Volume  \
# 0                   AAPL                  KO                 SPY       AAPL
# 1                    NaN                 NaN                 NaN        NaN
# 2      6.389117292428329  17.352765231960646   84.07808344850892  493729600
# 3      6.424142229757467   17.25865033111413   84.74401138748014  601904800
# 4      6.417556632241553    17.1068549260916   84.93855432563618  552160000
# ...                  ...                 ...                 ...        ...
# 2766  127.59672197110412   45.30414032429653   342.6581462095984   54930100
# 2767   130.1910087492954   46.01335249970111  346.06534457269254  124486200
# 2768   134.1359124001807   46.52603258810751   347.9924491984202  121047300
# 2769  131.73594502265215   46.18424657144978  346.62395879952305   96452100
# 2770  130.27846074381847   46.52603582503338   346.1026197103733   99116600
#
#       Volume.1   Volume.2
# 0           KO        SPY
# 1          NaN        NaN
# 2     13870400  118944600
# 3     23172400  111579900
# 4     19264600  116074400
# ...        ...        ...
# 2766   3265500   26457900
# 2767   9020500   39000400
# 2768   8320600   53680500
# 2769   8142700   49455300
# 2770   8495000   78520700
#
# [2771 rows x 16 columns]

# %%
stocks = pd.read_csv("stocksYT.csv",header=[0,1])
stocks
# Out:
#            Price       Close                               High             \
#           Ticker        AAPL         KO         SPY        AAPL         KO
# 0           Date         NaN        NaN         NaN         NaN        NaN
# 1     2010-01-04    6.406480  17.316336   84.796379    6.421148  17.370981
# 2     2010-01-05    6.417556  17.106859   85.020851    6.453778  17.301153
# 3     2010-01-06    6.315477  17.100784   85.080719    6.443002  17.134177
# 4     2010-01-07    6.303801  17.058292   85.439857    6.346310  17.112937
# ...          ...         ...        ...         ...         ...        ...
# 2765  2020-12-24  128.228287  45.663017  343.514618  129.676046  45.757010
# 2766  2020-12-28  132.814453  46.278240  346.465668  133.446018  46.517492
# 2767  2020-12-29  131.046066  46.252602  345.804749  134.854922  46.560212
# 2768  2020-12-30  129.928680  46.517490  346.298126  132.134324  46.679842
# 2769  2020-12-31  128.927872  46.859280  348.057587  130.919751  46.936182
#
#                          Low                               Open             \
#              SPY        AAPL         KO         SPY        AAPL         KO
# 0            NaN         NaN        NaN         NaN         NaN        NaN
# 1      84.841271    6.357685  17.273834   83.434609    6.389117  17.352765
# 2      85.058265    6.383729  17.043107   84.437236    6.424142  17.258650
# 3      85.290221    6.308891  16.994530   84.871217    6.417557  17.106855
# 4      85.544609    6.258000  16.924717   84.684148    6.338826  17.100795
# ...          ...         ...        ...         ...         ...        ...
# 2765  343.542545  127.382958  45.304140  342.071682  127.596722  45.304140
# 2766  346.856644  129.724607  45.910817  345.441635  130.191009  46.013352
# 2767  348.169329  130.531094  46.158609  345.218256  134.135912  46.526033
# 2768  347.331478  129.617746  46.167157  345.907150  131.735945  46.184247
# 2769  348.783714  127.985373  46.372230  345.590617  130.278461  46.526036
#
#                        Volume
#              SPY         AAPL          KO          SPY
# 0            NaN          NaN         NaN          NaN
# 1      84.078083  493729600.0  13870400.0  118944600.0
# 2      84.744011  601904800.0  23172400.0  111579900.0
# 3      84.938554  552160000.0  19264600.0  116074400.0
# 4      84.923580  477131200.0  13234600.0  131091100.0
# ...          ...          ...         ...          ...
# 2765  342.658146   54930100.0   3265500.0   26457900.0
# 2766  346.065345  124486200.0   9020500.0   39000400.0
# 2767  347.992449  121047300.0   8320600.0   53680500.0
# 2768  346.623959   96452100.0   8142700.0   49455300.0
# 2769  346.102620   99116600.0   8495000.0   78520700.0
#
# [2770 rows x 16 columns]

# %%
stocks = pd.read_csv("stocksYT.csv",header=[0,1])
stocks
# Out:
#            Price       Close                               High             \
#           Ticker        AAPL         KO         SPY        AAPL         KO
# 0           Date         NaN        NaN         NaN         NaN        NaN
# 1     2010-01-04    6.406480  17.316336   84.796379    6.421148  17.370981
# 2     2010-01-05    6.417556  17.106859   85.020851    6.453778  17.301153
# 3     2010-01-06    6.315477  17.100784   85.080719    6.443002  17.134177
# 4     2010-01-07    6.303801  17.058292   85.439857    6.346310  17.112937
# ...          ...         ...        ...         ...         ...        ...
# 2765  2020-12-24  128.228287  45.663017  343.514618  129.676046  45.757010
# 2766  2020-12-28  132.814453  46.278240  346.465668  133.446018  46.517492
# 2767  2020-12-29  131.046066  46.252602  345.804749  134.854922  46.560212
# 2768  2020-12-30  129.928680  46.517490  346.298126  132.134324  46.679842
# 2769  2020-12-31  128.927872  46.859280  348.057587  130.919751  46.936182
#
#                          Low                               Open             \
#              SPY        AAPL         KO         SPY        AAPL         KO
# 0            NaN         NaN        NaN         NaN         NaN        NaN
# 1      84.841271    6.357685  17.273834   83.434609    6.389117  17.352765
# 2      85.058265    6.383729  17.043107   84.437236    6.424142  17.258650
# 3      85.290221    6.308891  16.994530   84.871217    6.417557  17.106855
# 4      85.544609    6.258000  16.924717   84.684148    6.338826  17.100795
# ...          ...         ...        ...         ...         ...        ...
# 2765  343.542545  127.382958  45.304140  342.071682  127.596722  45.304140
# 2766  346.856644  129.724607  45.910817  345.441635  130.191009  46.013352
# 2767  348.169329  130.531094  46.158609  345.218256  134.135912  46.526033
# 2768  347.331478  129.617746  46.167157  345.907150  131.735945  46.184247
# 2769  348.783714  127.985373  46.372230  345.590617  130.278461  46.526036
#
#                        Volume
#              SPY         AAPL          KO          SPY
# 0            NaN          NaN         NaN          NaN
# 1      84.078083  493729600.0  13870400.0  118944600.0
# 2      84.744011  601904800.0  23172400.0  111579900.0
# 3      84.938554  552160000.0  19264600.0  116074400.0
# 4      84.923580  477131200.0  13234600.0  131091100.0
# ...          ...          ...         ...          ...
# 2765  342.658146   54930100.0   3265500.0   26457900.0
# 2766  346.065345  124486200.0   9020500.0   39000400.0
# 2767  347.992449  121047300.0   8320600.0   53680500.0
# 2768  346.623959   96452100.0   8142700.0   49455300.0
# 2769  346.102620   99116600.0   8495000.0   78520700.0
#
# [2770 rows x 16 columns]

# %%
stocks = pd.read_csv("stocksYT.csv",header=[0,1],index_col=[0])
stocks
# Out:
# Price            Close                               High             \
# Ticker            AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.406480  17.316336   84.796379    6.421148  17.370981
# 2010-01-05    6.417556  17.106859   85.020851    6.453778  17.301153
# 2010-01-06    6.315477  17.100784   85.080719    6.443002  17.134177
# 2010-01-07    6.303801  17.058292   85.439857    6.346310  17.112937
# 2010-01-08    6.345710  16.742567   85.724182    6.346309  16.891322
# ...                ...        ...         ...         ...        ...
# 2020-12-24  128.228287  45.663017  343.514618  129.676046  45.757010
# 2020-12-28  132.814453  46.278240  346.465668  133.446018  46.517492
# 2020-12-29  131.046066  46.252602  345.804749  134.854922  46.560212
# 2020-12-30  129.928680  46.517490  346.298126  132.134324  46.679842
# 2020-12-31  128.927872  46.859280  348.057587  130.919751  46.936182
#
# Price                          Low                               Open  \
# Ticker             SPY        AAPL         KO         SPY        AAPL
# Date
# 2010-01-04   84.841271    6.357685  17.273834   83.434609    6.389117
# 2010-01-05   85.058265    6.383729  17.043107   84.437236    6.424142
# 2010-01-06   85.290221    6.308891  16.994530   84.871217    6.417557
# 2010-01-07   85.544609    6.258000  16.924717   84.684148    6.338826
# 2010-01-08   85.761596    6.258299  16.621134   85.043300    6.295418
# ...                ...         ...        ...         ...         ...
# 2020-12-24  343.542545  127.382958  45.304140  342.071682  127.596722
# 2020-12-28  346.856644  129.724607  45.910817  345.441635  130.191009
# 2020-12-29  348.169329  130.531094  46.158609  345.218256  134.135912
# 2020-12-30  347.331478  129.617746  46.167157  345.907150  131.735945
# 2020-12-31  348.783714  127.985373  46.372230  345.590617  130.278461
#
# Price                                 Volume
# Ticker             KO         SPY       AAPL        KO        SPY
# Date
# 2010-01-04  17.352765   84.078083  493729600  13870400  118944600
# 2010-01-05  17.258650   84.744011  601904800  23172400  111579900
# 2010-01-06  17.106855   84.938554  552160000  19264600  116074400
# 2010-01-07  17.100795   84.923580  477131200  13234600  131091100
# 2010-01-08  16.836677   85.215389  447610800  28712400  126402800
# ...               ...         ...        ...       ...        ...
# 2020-12-24  45.304140  342.658146   54930100   3265500   26457900
# 2020-12-28  46.013352  346.065345  124486200   9020500   39000400
# 2020-12-29  46.526033  347.992449  121047300   8320600   53680500
# 2020-12-30  46.184247  346.623959   96452100   8142700   49455300
# 2020-12-31  46.526036  346.102620   99116600   8495000   78520700
#
# [2769 rows x 15 columns]

# %%
stocks = pd.read_csv("stocksYT.csv",header=[0,1],index_col=[0], parse_dates=[0])
stocks
# Out:
# Price            Close                               High             \
# Ticker            AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.406480  17.316336   84.796379    6.421148  17.370981
# 2010-01-05    6.417556  17.106859   85.020851    6.453778  17.301153
# 2010-01-06    6.315477  17.100784   85.080719    6.443002  17.134177
# 2010-01-07    6.303801  17.058292   85.439857    6.346310  17.112937
# 2010-01-08    6.345710  16.742567   85.724182    6.346309  16.891322
# ...                ...        ...         ...         ...        ...
# 2020-12-24  128.228287  45.663017  343.514618  129.676046  45.757010
# 2020-12-28  132.814453  46.278240  346.465668  133.446018  46.517492
# 2020-12-29  131.046066  46.252602  345.804749  134.854922  46.560212
# 2020-12-30  129.928680  46.517490  346.298126  132.134324  46.679842
# 2020-12-31  128.927872  46.859280  348.057587  130.919751  46.936182
#
# Price                          Low                               Open  \
# Ticker             SPY        AAPL         KO         SPY        AAPL
# Date
# 2010-01-04   84.841271    6.357685  17.273834   83.434609    6.389117
# 2010-01-05   85.058265    6.383729  17.043107   84.437236    6.424142
# 2010-01-06   85.290221    6.308891  16.994530   84.871217    6.417557
# 2010-01-07   85.544609    6.258000  16.924717   84.684148    6.338826
# 2010-01-08   85.761596    6.258299  16.621134   85.043300    6.295418
# ...                ...         ...        ...         ...         ...
# 2020-12-24  343.542545  127.382958  45.304140  342.071682  127.596722
# 2020-12-28  346.856644  129.724607  45.910817  345.441635  130.191009
# 2020-12-29  348.169329  130.531094  46.158609  345.218256  134.135912
# 2020-12-30  347.331478  129.617746  46.167157  345.907150  131.735945
# 2020-12-31  348.783714  127.985373  46.372230  345.590617  130.278461
#
# Price                                 Volume
# Ticker             KO         SPY       AAPL        KO        SPY
# Date
# 2010-01-04  17.352765   84.078083  493729600  13870400  118944600
# 2010-01-05  17.258650   84.744011  601904800  23172400  111579900
# 2010-01-06  17.106855   84.938554  552160000  19264600  116074400
# 2010-01-07  17.100795   84.923580  477131200  13234600  131091100
# 2010-01-08  16.836677   85.215389  447610800  28712400  126402800
# ...               ...         ...        ...       ...        ...
# 2020-12-24  45.304140  342.658146   54930100   3265500   26457900
# 2020-12-28  46.013352  346.065345  124486200   9020500   39000400
# 2020-12-29  46.526033  347.992449  121047300   8320600   53680500
# 2020-12-30  46.184247  346.623959   96452100   8142700   49455300
# 2020-12-31  46.526036  346.102620   99116600   8495000   78520700
#
# [2769 rows x 15 columns]

# %%
stocks.columns
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             ( 'Close',   'KO'),
#             ( 'Close',  'SPY'),
#             (  'High', 'AAPL'),
#             (  'High',   'KO'),
#             (  'High',  'SPY'),
#             (   'Low', 'AAPL'),
#             (   'Low',   'KO'),
#             (   'Low',  'SPY'),
#             (  'Open', 'AAPL'),
#             (  'Open',   'KO'),
#             (  'Open',  'SPY'),
#             ('Volume', 'AAPL'),
#             ('Volume',   'KO'),
#             ('Volume',  'SPY')],
#            names=['Price', 'Ticker'])

# %%
#Convert multi index to one tuple
stocks.columns=stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([ ('Close', 'AAPL'),    ('Close', 'KO'),   ('Close', 'SPY'),
#          ('High', 'AAPL'),     ('High', 'KO'),    ('High', 'SPY'),
#           ('Low', 'AAPL'),      ('Low', 'KO'),     ('Low', 'SPY'),
#          ('Open', 'AAPL'),     ('Open', 'KO'),    ('Open', 'SPY'),
#        ('Volume', 'AAPL'),   ('Volume', 'KO'),  ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2010-01-04       6.406480    17.316336     84.796379      6.421148
# 2010-01-05       6.417556    17.106859     85.020851      6.453778
# 2010-01-06       6.315477    17.100784     85.080719      6.443002
# 2010-01-07       6.303801    17.058292     85.439857      6.346310
# 2010-01-08       6.345710    16.742567     85.724182      6.346309
# ...                   ...          ...           ...           ...
# 2020-12-24     128.228287    45.663017    343.514618    129.676046
# 2020-12-28     132.814453    46.278240    346.465668    133.446018
# 2020-12-29     131.046066    46.252602    345.804749    134.854922
# 2020-12-30     129.928680    46.517490    346.298126    132.134324
# 2020-12-31     128.927872    46.859280    348.057587    130.919751
#
#             (High, KO)  (High, SPY)  (Low, AAPL)  (Low, KO)  (Low, SPY)  \
# Date
# 2010-01-04   17.370981    84.841271     6.357685  17.273834   83.434609
# 2010-01-05   17.301153    85.058265     6.383729  17.043107   84.437236
# 2010-01-06   17.134177    85.290221     6.308891  16.994530   84.871217
# 2010-01-07   17.112937    85.544609     6.258000  16.924717   84.684148
# 2010-01-08   16.891322    85.761596     6.258299  16.621134   85.043300
# ...                ...          ...          ...        ...         ...
# 2020-12-24   45.757010   343.542545   127.382958  45.304140  342.071682
# 2020-12-28   46.517492   346.856644   129.724607  45.910817  345.441635
# 2020-12-29   46.560212   348.169329   130.531094  46.158609  345.218256
# 2020-12-30   46.679842   347.331478   129.617746  46.167157  345.907150
# 2020-12-31   46.936182   348.783714   127.985373  46.372230  345.590617
#
#             (Open, AAPL)  (Open, KO)  (Open, SPY)  (Volume, AAPL)  \
# Date
# 2010-01-04      6.389117   17.352765    84.078083       493729600
# 2010-01-05      6.424142   17.258650    84.744011       601904800
# 2010-01-06      6.417557   17.106855    84.938554       552160000
# 2010-01-07      6.338826   17.100795    84.923580       477131200
# 2010-01-08      6.295418   16.836677    85.215389       447610800
# ...                  ...         ...          ...             ...
# 2020-12-24    127.596722   45.304140   342.658146        54930100
# 2020-12-28    130.191009   46.013352   346.065345       124486200
# 2020-12-29    134.135912   46.526033   347.992449       121047300
# 2020-12-30    131.735945   46.184247   346.623959        96452100
# 2020-12-31    130.278461   46.526036   346.102620        99116600
#
#             (Volume, KO)  (Volume, SPY)
# Date
# 2010-01-04      13870400      118944600
# 2010-01-05      23172400      111579900
# 2010-01-06      19264600      116074400
# 2010-01-07      13234600      131091100
# 2010-01-08      28712400      126402800
# ...                  ...            ...
# 2020-12-24       3265500       26457900
# 2020-12-28       9020500       39000400
# 2020-12-29       8320600       53680500
# 2020-12-30       8142700       49455300
# 2020-12-31       8495000       78520700
#
# [2769 rows x 15 columns]

# %%
stocks.columns=pd.MultiIndex.from_tuples(stocks.columns)
stocks
# Out:
#                  Close                               High             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.406480  17.316336   84.796379    6.421148  17.370981
# 2010-01-05    6.417556  17.106859   85.020851    6.453778  17.301153
# 2010-01-06    6.315477  17.100784   85.080719    6.443002  17.134177
# 2010-01-07    6.303801  17.058292   85.439857    6.346310  17.112937
# 2010-01-08    6.345710  16.742567   85.724182    6.346309  16.891322
# ...                ...        ...         ...         ...        ...
# 2020-12-24  128.228287  45.663017  343.514618  129.676046  45.757010
# 2020-12-28  132.814453  46.278240  346.465668  133.446018  46.517492
# 2020-12-29  131.046066  46.252602  345.804749  134.854922  46.560212
# 2020-12-30  129.928680  46.517490  346.298126  132.134324  46.679842
# 2020-12-31  128.927872  46.859280  348.057587  130.919751  46.936182
#
#                                Low                               Open  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2010-01-04   84.841271    6.357685  17.273834   83.434609    6.389117
# 2010-01-05   85.058265    6.383729  17.043107   84.437236    6.424142
# 2010-01-06   85.290221    6.308891  16.994530   84.871217    6.417557
# 2010-01-07   85.544609    6.258000  16.924717   84.684148    6.338826
# 2010-01-08   85.761596    6.258299  16.621134   85.043300    6.295418
# ...                ...         ...        ...         ...         ...
# 2020-12-24  343.542545  127.382958  45.304140  342.071682  127.596722
# 2020-12-28  346.856644  129.724607  45.910817  345.441635  130.191009
# 2020-12-29  348.169329  130.531094  46.158609  345.218256  134.135912
# 2020-12-30  347.331478  129.617746  46.167157  345.907150  131.735945
# 2020-12-31  348.783714  127.985373  46.372230  345.590617  130.278461
#
#                                       Volume
#                    KO         SPY       AAPL        KO        SPY
# Date
# 2010-01-04  17.352765   84.078083  493729600  13870400  118944600
# 2010-01-05  17.258650   84.744011  601904800  23172400  111579900
# 2010-01-06  17.106855   84.938554  552160000  19264600  116074400
# 2010-01-07  17.100795   84.923580  477131200  13234600  131091100
# 2010-01-08  16.836677   85.215389  447610800  28712400  126402800
# ...               ...         ...        ...       ...        ...
# 2020-12-24  45.304140  342.658146   54930100   3265500   26457900
# 2020-12-28  46.013352  346.065345  124486200   9020500   39000400
# 2020-12-29  46.526033  347.992449  121047300   8320600   53680500
# 2020-12-30  46.184247  346.623959   96452100   8142700   49455300
# 2020-12-31  46.526036  346.102620   99116600   8495000   78520700
#
# [2769 rows x 15 columns]

# %%
stocks.describe()
# Out:
#              Close                                   High               \
#               AAPL           KO          SPY         AAPL           KO
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean     31.209296    30.151208   177.176536    31.521688    30.345824
# std      24.339288     7.660934    67.836734    24.657194     7.728751
# min       5.749098    15.327826    77.148872     5.867343    15.525408
# 25%      15.031178    24.905939   111.804428    15.155576    25.035288
# 50%      24.274477    29.739460   171.267807    24.591182    29.878855
# 75%      40.473503    35.224747   235.453140    40.802386    35.397420
# max     132.814453    49.679375   348.057587   134.854922    49.679375
#
#                             Low                                   Open  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean    178.067691    30.871132    29.947086   176.149736    31.196247
# std      68.210426    23.992331     7.596803    67.447282    24.328370
# min      78.069829     5.695216    15.269224    76.341104     5.758679
# 25%     112.294580    14.874609    24.732756   111.234318    14.989674
# 50%     172.173750    24.053194    29.507770   170.436721    24.340866
# 75%     236.705740    40.206294    35.032797   233.728073    40.454722
# max     352.321181   130.531094    49.258008   345.907150   134.135912
#
#                                        Volume
#                 KO          SPY          AAPL            KO           SPY
# count  2769.000000  2769.000000  2.769000e+03  2.769000e+03  2.769000e+03
# mean     30.147744   177.153077  2.866162e+08  1.502133e+07  1.244573e+08
# std       7.663109    67.850714  2.289459e+08  6.716946e+06  7.477756e+07
# min      15.416592    77.835817  4.544800e+07  2.996300e+06  2.027000e+07
# 25%      24.873269   111.764890  1.211120e+08  1.071810e+07  7.292670e+07
# 50%      29.634891   171.185008  2.029972e+08  1.350830e+07  1.045961e+08
# 75%      35.224738   235.655631  3.890376e+08  1.751480e+07  1.539926e+08
# max      49.414981   347.992449  1.880998e+09  9.896750e+07  7.178287e+08

# %%
 close=stocks.loc[:,"Close"].copy()

# %%
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    6.406480  17.316336   84.796379
# 2010-01-05    6.417556  17.106859   85.020851
# 2010-01-06    6.315477  17.100784   85.080719
# 2010-01-07    6.303801  17.058292   85.439857
# 2010-01-08    6.345710  16.742567   85.724182
# ...                ...        ...         ...
# 2020-12-24  128.228287  45.663017  343.514618
# 2020-12-28  132.814453  46.278240  346.465668
# 2020-12-29  131.046066  46.252602  345.804749
# 2020-12-30  129.928680  46.517490  346.298126
# 2020-12-31  128.927872  46.859280  348.057587
#
# [2769 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
close.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
close.iloc[0,0]
# Out:
# np.float64(6.406479835510254)

# %%
close.AAPL
# Out:
# Date
# 2010-01-04      6.406480
# 2010-01-05      6.417556
# 2010-01-06      6.315477
# 2010-01-07      6.303801
# 2010-01-08      6.345710
#                  ...
# 2020-12-24    128.228287
# 2020-12-28    132.814453
# 2020-12-29    131.046066
# 2020-12-30    129.928680
# 2020-12-31    128.927872
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2010-01-04     100.000000
# 2010-01-05     100.172894
# 2010-01-06      98.579517
# 2010-01-07      98.397267
# 2010-01-08      99.051429
#                  ...
# 2020-12-24    2001.540472
# 2020-12-28    2073.126842
# 2020-12-29    2045.523745
# 2020-12-30    2028.082250
# 2020-12-31    2012.460431
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL     6.406480
# KO      17.316336
# SPY     84.796379
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
# Out:
#                    AAPL          KO         SPY
# Date
# 2010-01-04   100.000000  100.000000  100.000000
# 2010-01-05   100.172894   98.790296  100.264719
# 2010-01-06    98.579517   98.755214  100.335321
# 2010-01-07    98.397267   98.509827  100.758851
# 2010-01-08    99.051429   96.686547  101.094154
# ...                 ...         ...         ...
# 2020-12-24  2001.540472  263.699077  405.105291
# 2020-12-28  2073.126842  267.251924  408.585451
# 2020-12-29  2045.523745  267.103864  407.806032
# 2020-12-30  2028.082250  268.633568  408.387870
# 2020-12-31  2012.460431  270.607365  410.462794
#
# [2769 rows x 3 columns]

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
aapl= close.AAPL.copy().to_frame()

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    6.406480
# 2010-01-05    6.417556
# 2010-01-06    6.315477
# 2010-01-07    6.303801
# 2010-01-08    6.345710
# ...                ...
# 2020-12-24  128.228287
# 2020-12-28  132.814453
# 2020-12-29  131.046066
# 2020-12-30  129.928680
# 2020-12-31  128.927872
#
# [2769 rows x 1 columns]

# %%
aapl.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    6.406480
# 2010-01-06    6.417556
# 2010-01-07    6.315477
# 2010-01-08    6.303801
# ...                ...
# 2020-12-24  127.246925
# 2020-12-28  128.228287
# 2020-12-29  132.814453
# 2020-12-30  131.046066
# 2020-12-31  129.928680
#
# [2769 rows x 1 columns]

# %%
aapl["lag1"]=aapl.shift(periods=1)

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    6.406480         NaN
# 2010-01-05    6.417556    6.406480
# 2010-01-06    6.315477    6.417556
# 2010-01-07    6.303801    6.315477
# 2010-01-08    6.345710    6.303801
# ...                ...         ...
# 2020-12-24  128.228287  127.246925
# 2020-12-28  132.814453  128.228287
# 2020-12-29  131.046066  132.814453
# 2020-12-30  129.928680  131.046066
# 2020-12-31  128.927872  129.928680
#
# [2769 rows x 2 columns]

# %%
aapl["Diff"]=aapl.AAPL.sub(aapl.lag1)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2010-01-04    6.406480         NaN       NaN
# 2010-01-05    6.417556    6.406480  0.011076
# 2010-01-06    6.315477    6.417556 -0.102079
# 2010-01-07    6.303801    6.315477 -0.011676
# 2010-01-08    6.345710    6.303801  0.041909
# ...                ...         ...       ...
# 2020-12-24  128.228287  127.246925  0.981361
# 2020-12-28  132.814453  128.228287  4.586166
# 2020-12-29  131.046066  132.814453 -1.768387
# 2020-12-30  129.928680  131.046066 -1.117386
# 2020-12-31  128.927872  129.928680 -1.000809
#
# [2769 rows x 3 columns]

# %%
aapl["% Change"]=aapl.AAPL.div(aapl.lag1)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change
# Date
# 2010-01-04    6.406480         NaN       NaN       NaN
# 2010-01-05    6.417556    6.406480  0.011076  1.001729
# 2010-01-06    6.315477    6.417556 -0.102079  0.984094
# 2010-01-07    6.303801    6.315477 -0.011676  0.998151
# 2010-01-08    6.345710    6.303801  0.041909  1.006648
# ...                ...         ...       ...       ...
# 2020-12-24  128.228287  127.246925  0.981361  1.007712
# 2020-12-28  132.814453  128.228287  4.586166  1.035766
# 2020-12-29  131.046066  132.814453 -1.768387  0.986685
# 2020-12-30  129.928680  131.046066 -1.117386  0.991473
# 2020-12-31  128.927872  129.928680 -1.000809  0.992297
#
# [2769 rows x 4 columns]

# %%
del aapl["lag1"]

# %%
aapl
# Out:
#                   AAPL      Diff  % Change
# Date
# 2010-01-04    6.406480       NaN       NaN
# 2010-01-05    6.417556  0.011076  1.001729
# 2010-01-06    6.315477 -0.102079  0.984094
# 2010-01-07    6.303801 -0.011676  0.998151
# 2010-01-08    6.345710  0.041909  1.006648
# ...                ...       ...       ...
# 2020-12-24  128.228287  0.981361  1.007712
# 2020-12-28  132.814453  4.586166  1.035766
# 2020-12-29  131.046066 -1.768387  0.986685
# 2020-12-30  129.928680 -1.117386  0.991473
# 2020-12-31  128.927872 -1.000809  0.992297
#
# [2769 rows x 3 columns]

# %%
aapl.rename(columns = {'% Change': 'Change'}, inplace = True)

# %%
aapl
# Out:
#                   AAPL      Diff    Change
# Date
# 2010-01-04    6.406480       NaN       NaN
# 2010-01-05    6.417556  0.011076  1.001729
# 2010-01-06    6.315477 -0.102079  0.984094
# 2010-01-07    6.303801 -0.011676  0.998151
# 2010-01-08    6.345710  0.041909  1.006648
# ...                ...       ...       ...
# 2020-12-24  128.228287  0.981361  1.007712
# 2020-12-28  132.814453  4.586166  1.035766
# 2020-12-29  131.046066 -1.768387  0.986685
# 2020-12-30  129.928680 -1.117386  0.991473
# 2020-12-31  128.927872 -1.000809  0.992297
#
# [2769 rows x 3 columns]

# %%
aapl.AAPL.resample("ME").last()
# Out:
# Date
# 2010-01-31      5.749399
# 2010-02-28      6.125386
# 2010-03-31      7.034824
# 2010-04-30      7.815841
# 2010-05-31      7.689812
#                  ...
# 2020-08-31    125.165398
# 2020-09-30    112.332642
# 2020-10-31    105.591331
# 2020-11-30    115.674576
# 2020-12-31    128.927872
# Freq: ME, Name: AAPL, Length: 132, dtype: float64

# %%
aapl.AAPL.resample("BME").last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539597
# 2010-03-31    14.847033
# 2010-04-30    11.102144
# 2010-05-31    -1.612476
#                 ...
# 2020-08-31    21.656938
# 2020-09-30   -10.252639
# 2020-10-30    -6.001203
# 2020-11-30     9.549311
# 2020-12-31    11.457397
# Freq: BME, Name: AAPL, Length: 132, dtype: float64

# %%
del aapl["Change"]

# %%
del aapl["Diff"]

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    6.406480
# 2010-01-05    6.417556
# 2010-01-06    6.315477
# 2010-01-07    6.303801
# 2010-01-08    6.345710
# ...                ...
# 2020-12-24  128.228287
# 2020-12-28  132.814453
# 2020-12-29  131.046066
# 2020-12-30  129.928680
# 2020-12-31  128.927872
#
# [2769 rows x 1 columns]

# %%
ret = aapl.pct_change().dropna()

# %%
ret
# Out:
#                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# 2010-01-11 -0.008821
# ...              ...
# 2020-12-24  0.007712
# 2020-12-28  0.035766
# 2020-12-29 -0.013315
# 2020-12-30 -0.008527
# 2020-12-31 -0.007703
#
# [2768 rows x 1 columns]

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    6.406480
# 2010-01-05    6.417556
# 2010-01-06    6.315477
# 2010-01-07    6.303801
# 2010-01-08    6.345710
# ...                ...
# 2020-12-24  128.228287
# 2020-12-28  132.814453
# 2020-12-29  131.046066
# 2020-12-30  129.928680
# 2020-12-31  128.927872
#
# [2769 rows x 1 columns]

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2768 entries, 2010-01-05 to 2020-12-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2768 non-null   float64
# dtypes: float64(1)
# memory usage: 43.2 KB

# %%
ret.plot(kind="hist",figsize= (12, 8), bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
ret.mean()
# Out:
# AAPL    0.001244
# dtype: float64

# %%
daily_mean_ret=ret.mean()
daily_mean_ret
# Out:
# AAPL    0.001244
# dtype: float64

# %%
var_daily=ret.var()
var_daily
# Out:
# AAPL    0.000318
# dtype: float64

# %%
std_daily=np.sqrt(var_daily)

# %%
std_daily
# Out:
# AAPL    0.01783
# dtype: float64

# %%
ret.std()
# Out:
# AAPL    0.01783
# dtype: float64

# %%
annual_mean_ret=daily_mean_ret*252
annual_mean_ret
# Out:
# AAPL    0.313545
# dtype: float64

# %%
annual_var_return=var_daily*252
annual_var_return
# Out:
# AAPL    0.080117
# dtype: float64

# %%
annual_std_returns=np.sqrt(annual_var_return)

# %%
annual_std_returns
# Out:
# AAPL    0.28305
# dtype: float64

# %%
ret.std()*np.sqrt(252)
# Out:
# AAPL    0.28305
# dtype: float64

# %%
ticker=["SPY","AAPL","KO","IBM","DIS", "MSFT"]

# %%
stocks = yf.download(ticker, start = "2010-01-01", end ="2021-01-01")
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
stocks
# Out:
# Price            Close                                                \
# Ticker            AAPL         DIS        IBM         KO        MSFT
# Date
# 2010-01-04    6.406480   27.291229  71.938835  17.316336   23.077387
# 2010-01-05    6.417556   27.223154  71.069832  17.106859   23.084837
# 2010-01-06    6.315477   27.078480  70.608154  17.100784   22.943174
# 2010-01-07    6.303801   27.086992  70.363770  17.058292   22.704565
# 2010-01-08    6.345710   27.129538  71.069832  16.742567   22.861149
# ...                ...         ...        ...        ...         ...
# 2020-12-24  128.228287  169.732895  95.665131  45.663017  213.250748
# 2020-12-28  132.814453  174.744858  95.764877  46.278240  215.366516
# 2020-12-29  131.046066  173.220764  94.982300  46.252602  214.591049
# 2020-12-30  129.928680  177.001724  95.396599  46.517490  212.226395
# 2020-12-31  128.927872  177.011475  96.578133  46.859280  212.934845
#
# Price                         High                                    ...  \
# Ticker             SPY        AAPL         DIS        IBM         KO  ...
# Date                                                                  ...
# 2010-01-04   84.796379    6.421148   27.869902  72.221267  17.370981  ...
# 2010-01-05   85.020851    6.453778   27.367822  71.612972  17.301153  ...
# 2010-01-06   85.080719    6.443002   27.231658  71.417434  17.134177  ...
# 2010-01-07   85.439857    6.346310   27.112523  70.743965  17.112937  ...
# 2010-01-08   85.724182    6.346309   27.180598  71.107849  16.891322  ...
# ...                ...         ...         ...        ...        ...  ...
# 2020-12-24  343.514618  129.676046  170.563344  95.979697  45.757010  ...
# 2020-12-28  346.465668  133.446018  175.780467  97.130530  46.517492  ...
# 2020-12-29  345.804749  134.854922  176.054036  96.271235  46.560212  ...
# 2020-12-30  346.298126  132.134324  179.180413  95.787883  46.679842  ...
# 2020-12-31  348.057587  130.919751  179.180399  96.693215  46.936182  ...
#
# Price            Open                                        Volume            \
# Ticker            IBM         KO        MSFT         SPY       AAPL       DIS
# Date
# 2010-01-04  71.249048  17.352765   22.831328   84.078083  493729600  13700400
# 2010-01-05  71.520636  17.258650   23.002818   84.744011  601904800  10307700
# 2010-01-06  70.977488  17.106855   23.025193   84.938554  552160000  10709500
# 2010-01-07  70.537572  17.100795   22.838778   84.923580  477131200   8202100
# 2010-01-08  70.103043  16.836677   22.577808   85.215389  447610800   7657500
# ...               ...        ...         ...         ...        ...       ...
# 2020-12-24  95.902973  45.304140  211.977464  342.658146   54930100   2721000
# 2020-12-28  95.979699  46.013352  214.878256  346.065345  124486200  13145400
# 2020-12-29  96.171496  46.526033  216.658939  347.992449  121047300   6875400
# 2020-12-30  94.982299  46.184247  215.625007  346.623959   96452100  11680400
# 2020-12-31  95.304541  46.526036  212.245548  346.102620   99116600   7073500
#
# Price
# Ticker          IBM        KO      MSFT        SPY
# Date
# 2010-01-04  6438444  13870400  38409100  118944600
# 2010-01-05  7156104  23172400  49749600  111579900
# 2010-01-06  5863144  19264600  58182400  116074400
# 2010-01-07  6109268  13234600  50559700  131091100
# 2010-01-08  4390271  28712400  51197400  126402800
# ...             ...       ...       ...        ...
# 2020-12-24  1842111   3265500  10550600   26457900
# 2020-12-28  3781499   9020500  17933500   39000400
# 2020-12-29  3647402   8320600  17403200   53680500
# 2020-12-30  3535794   8142700  20272300   49455300
# 2020-12-31  3738822   8495000  20942100   78520700
#
# [2769 rows x 30 columns]

# %%
close=stocks.loc[:,"Close"].copy()

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret=close.pct_change().dropna()
ret.head()
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002494 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003461 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010034 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397

# %%
ret.describe().T
# Out:
#          count      mean       std       min       25%       50%       75%  \
# Ticker
# AAPL    2768.0  0.001244  0.017830 -0.128647 -0.006954  0.000961  0.010409
# DIS     2768.0  0.000798  0.015702 -0.129846 -0.006172  0.000684  0.007913
# IBM     2768.0  0.000206  0.014090 -0.128507 -0.006143  0.000392  0.006829
# KO      2768.0  0.000421  0.011053 -0.096725 -0.004521  0.000484  0.005735
# MSFT    2768.0  0.000931  0.015993 -0.147390 -0.006808  0.000689  0.008671
# SPY     2768.0  0.000570  0.010870 -0.109424 -0.003423  0.000700  0.005452
#
#              max
# Ticker
# AAPL    0.119808
# DIS     0.144123
# IBM     0.113011
# KO      0.064796
# MSFT    0.142169
# SPY     0.090603

# %%
summary=ret.describe().T.loc[:,["mean","std"]]

# %%
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.001244  0.017830
# DIS     0.000798  0.015702
# IBM     0.000206  0.014090
# KO      0.000421  0.011053
# MSFT    0.000931  0.015993
# SPY     0.000570  0.010870

# %%
summary["mean"]=summary["mean"]*252
summary["std"]=summary["std"]*np.sqrt(252)

# %%
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.313545  0.283050
# DIS     0.201212  0.249255
# IBM     0.051943  0.223671
# KO      0.106110  0.175462
# MSFT    0.234610  0.253888
# SPY     0.143546  0.172551

# %%
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size=15)
plt.xlabel("Annual risk(std)",fontsize =15)
plt.ylabel("Annual return",fontsize =15)
plt.title("Risk/return",fontsize=25)
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ##Correlation and Covarience

# %%
ret
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002494 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003461 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010034 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-24  0.007712  0.001037  0.006376  0.006782  0.007827  0.003890
# 2020-12-28  0.035766  0.029529  0.001043  0.013473  0.009922  0.008591
# 2020-12-29 -0.013315 -0.008722 -0.008172 -0.000554 -0.003601 -0.001908
# 2020-12-30 -0.008527  0.021827  0.004362  0.005727 -0.011019  0.001427
# 2020-12-31 -0.007703  0.000055  0.012385  0.007348  0.003338  0.005081
#
# [2768 rows x 6 columns]

# %%
ret.cov()
# Out:
# Ticker      AAPL       DIS       IBM        KO      MSFT       SPY
# Ticker
# AAPL    0.000318  0.000115  0.000110  0.000068  0.000159  0.000128
# DIS     0.000115  0.000247  0.000111  0.000086  0.000121  0.000121
# IBM     0.000110  0.000111  0.000199  0.000079  0.000120  0.000108
# KO      0.000068  0.000086  0.000079  0.000122  0.000077  0.000078
# MSFT    0.000159  0.000121  0.000120  0.000077  0.000256  0.000130
# SPY     0.000128  0.000121  0.000108  0.000078  0.000130  0.000118

# %%
ret.corr()
# Out:
# Ticker      AAPL       DIS       IBM        KO      MSFT       SPY
# Ticker
# AAPL    1.000000  0.409407  0.435915  0.345102  0.556477  0.659223
# DIS     0.409407  1.000000  0.501432  0.493058  0.480983  0.706340
# IBM     0.435915  0.501432  1.000000  0.509002  0.533284  0.704534
# KO      0.345102  0.493058  0.509002  1.000000  0.435529  0.645947
# MSFT    0.556477  0.480983  0.533284  0.435529  1.000000  0.746678
# SPY     0.659223  0.706340  0.704534  0.645947  0.746678  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap="Reds", annot=True,annot_kws={"size":15},vmax=0.6)
plt.show()

# %%
#here we should have stocks which are less related because 
#we want variety , if one breaks other will stay strong

# %% [markdown]
# ## Simple returns and long returns

# %%
df = pd.DataFrame(index=[2016,2017,2018],data=[100,50,95],columns=["Price"])

# %%
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simplereturn=df.pct_change().dropna()

# %%
simplereturn
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simplereturn.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
#mean return are misleading

# %%
logreturns=np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)
# Out:
# Price    95.0
# dtype: float64

# %%
 SPY = yf.download("SPY",period="max")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
 SPY
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker             SPY         SPY         SPY         SPY       SPY
# Date
# 1993-01-29   24.175385   24.192579   24.072218   24.192579   1003200
# 1993-02-01   24.347332   24.347332   24.192582   24.192582    480500
# 1993-02-02   24.398912   24.416107   24.278551   24.330135    201300
# 1993-02-03   24.656834   24.674028   24.416111   24.433306    529400
# 1993-02-04   24.759995   24.811578   24.467689   24.742800    531500
# ...                ...         ...         ...         ...       ...
# 2026-05-11  739.299988  740.789978  736.450012  736.450012  44024000
# 2026-05-12  738.179993  738.840027  731.830017  736.890015  54185300
# 2026-05-13  742.309998  743.909973  735.469971  738.469971  44200200
# 2026-05-14  748.169983  749.530029  743.559998  743.650024  45307600
# 2026-05-15  739.169983  743.460022  737.960022  741.789978  60290000
#
# [8381 rows x 5 columns]

# %%
spy = SPY[('Close', 'SPY')].to_frame()

# %%
spy
# Out:
#                  Close
#                    SPY
# Date
# 1993-01-29   24.175385
# 1993-02-01   24.347332
# 1993-02-02   24.398912
# 1993-02-03   24.656834
# 1993-02-04   24.759995
# ...                ...
# 2026-05-11  739.299988
# 2026-05-12  738.179993
# 2026-05-13  742.309998
# 2026-05-14  748.169983
# 2026-05-15  739.169983
#
# [8381 rows x 1 columns]

# %%
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy_roll=spy.rolling(window=10)

# %%
spy_roll=spy_roll.mean()

# %%
spy_roll
# Out:
#                  Close
#                    SPY
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2026-05-11  724.669006
# 2026-05-12  727.318005
# 2026-05-13  730.391003
# 2026-05-14  733.342004
# 2026-05-15  735.194000
#
# [8381 rows x 1 columns]

# %%
spy.rolling(window=10).median()
# Out:
#                  Close
#                    SPY
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2026-05-11  722.210022
# 2026-05-12  727.675018
# 2026-05-13  732.705017
# 2026-05-14  735.725006
# 2026-05-15  737.899994
#
# [8381 rows x 1 columns]

# %%
spy.rolling(window=10).max()
# Out:
#                  Close
#                    SPY
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2026-05-11  739.299988
# 2026-05-12  739.299988
# 2026-05-13  742.309998
# 2026-05-14  748.169983
# 2026-05-15  748.169983
#
# [8381 rows x 1 columns]

# %%
 spy.rolling(window=10,min_periods=5).max()
# Out:
#                  Close
#                    SPY
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04   24.759995
# ...                ...
# 2026-05-11  739.299988
# 2026-05-12  739.299988
# 2026-05-13  742.309998
# 2026-05-14  748.169983
# 2026-05-15  748.169983
#
# [8381 rows x 1 columns]

# %%
spy["SMA50"]=spy.rolling(window=50,min_periods=50).mean()

# %%
spy
# Out:
#                  Close       SMA50
#                    SPY
# Date
# 1993-01-29   24.175385         NaN
# 1993-02-01   24.347332         NaN
# 1993-02-02   24.398912         NaN
# 1993-02-03   24.656834         NaN
# 1993-02-04   24.759995         NaN
# ...                ...         ...
# 2026-05-11  739.299988  684.832716
# 2026-05-12  738.179993  685.906104
# 2026-05-13  742.309998  687.182761
# 2026-05-14  748.169983  688.480881
# 2026-05-15  739.169983  689.675193
#
# [8381 rows x 2 columns]

# %%
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["SMA200"] = spy[("Close", "SPY")].rolling(window=200, min_periods=200).mean()

# %%
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["EMA50"]=spy.Close.ewm(span=100,min_periods=100).mean()

# %%
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["Day"]=spy.index.day_name()

# %%
spy["Quarter"]=spy.index.quarter

# %%
spy
# Out:
#                  Close       SMA50      SMA200       EMA50        Day Quarter
#                    SPY
# Date
# 1993-01-29   24.175385         NaN         NaN         NaN     Friday       1
# 1993-02-01   24.347332         NaN         NaN         NaN     Monday       1
# 1993-02-02   24.398912         NaN         NaN         NaN    Tuesday       1
# 1993-02-03   24.656834         NaN         NaN         NaN  Wednesday       1
# 1993-02-04   24.759995         NaN         NaN         NaN   Thursday       1
# ...                ...         ...         ...         ...        ...     ...
# 2026-05-11  739.299988  684.832716  671.107852  685.252612     Monday       2
# 2026-05-12  738.179993  685.906104  671.640045  686.300679    Tuesday       2
# 2026-05-13  742.309998  687.182761  672.193681  687.409774  Wednesday       2
# 2026-05-14  748.169983  688.480881  672.784946  688.612947   Thursday       2
# 2026-05-15  739.169983  689.675193  673.335178  689.614076     Friday       2
#
# [8381 rows x 6 columns]

# %%
spy = yf.download("SPY",period="max")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker             SPY         SPY         SPY         SPY       SPY
# Date
# 1993-01-29   24.175385   24.192579   24.072218   24.192579   1003200
# 1993-02-01   24.347328   24.347328   24.192578   24.192578    480500
# 1993-02-02   24.398909   24.416103   24.278548   24.330131    201300
# 1993-02-03   24.656837   24.674032   24.416115   24.433310    529400
# 1993-02-04   24.759995   24.811578   24.467689   24.742800    531500
# ...                ...         ...         ...         ...       ...
# 2026-05-11  739.299988  740.789978  736.450012  736.450012  44024000
# 2026-05-12  738.179993  738.840027  731.830017  736.890015  54185300
# 2026-05-13  742.309998  743.909973  735.469971  738.469971  44200200
# 2026-05-14  748.169983  749.530029  743.559998  743.650024  45307600
# 2026-05-15  739.169983  743.460022  737.960022  741.789978  60290000
#
# [8381 rows x 5 columns]

# %%
spy = SPY[('Close', 'SPY')].to_frame()

# %%
spy
# Out:
#                  Close
#                    SPY
# Date
# 1993-01-29   24.175385
# 1993-02-01   24.347332
# 1993-02-02   24.398912
# 1993-02-03   24.656834
# 1993-02-04   24.759995
# ...                ...
# 2026-05-11  739.299988
# 2026-05-12  738.179993
# 2026-05-13  742.309998
# 2026-05-14  748.169983
# 2026-05-15  739.169983
#
# [8381 rows x 1 columns]

# %%
all_days = pd.date_range(start="2010-12-31", end="2020-01-01", freq="D")
all_days
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-01', '2011-01-02', '2011-01-03',
#                '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07',
#                '2011-01-08', '2011-01-09',
#                ...
#                '2019-12-23', '2019-12-24', '2019-12-25', '2019-12-26',
#                '2019-12-27', '2019-12-28', '2019-12-29', '2019-12-30',
#                '2019-12-31', '2020-01-01'],
#               dtype='datetime64[ns]', length=3289, freq='D')

# %%
spy
# Out:
#                  Close
#                    SPY
# Date
# 1993-01-29   24.175385
# 1993-02-01   24.347332
# 1993-02-02   24.398912
# 1993-02-03   24.656834
# 1993-02-04   24.759995
# ...                ...
# 2026-05-11  739.299988
# 2026-05-12  738.179993
# 2026-05-13  742.309998
# 2026-05-14  748.169983
# 2026-05-15  739.169983
#
# [8381 rows x 1 columns]

# %%
spy=spy.reindex(all_days)

# %%
spy
# Out:
#                  Close
#                    SPY
# 2010-12-31   95.936378
# 2011-01-01         NaN
# 2011-01-02         NaN
# 2011-01-03   96.928177
# 2011-01-04   96.874786
# ...                ...
# 2019-12-28         NaN
# 2019-12-29         NaN
# 2019-12-30  293.424591
# 2019-12-31  294.137421
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
spy.fillna(method="ffill")
# Out:
# C:\Users\deboj\AppData\Local\Temp\ipykernel_12480\3731869003.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spy.fillna(method="ffill")
#                  Close
#                    SPY
# 2010-12-31   95.936378
# 2011-01-01   95.936378
# 2011-01-02   95.936378
# 2011-01-03   96.928177
# 2011-01-04   96.874786
# ...                ...
# 2019-12-28  295.051331
# 2019-12-29  295.051331
# 2019-12-30  293.424591
# 2019-12-31  294.137421
# 2020-01-01  294.137421
#
# [3289 rows x 1 columns]

# %%
 spy.fillna(method="bfill")
# Out:
# C:\Users\deboj\AppData\Local\Temp\ipykernel_12480\2565785233.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spy.fillna(method="bfill")
#                  Close
#                    SPY
# 2010-12-31   95.936378
# 2011-01-01   96.928177
# 2011-01-02   96.928177
# 2011-01-03   96.928177
# 2011-01-04   96.874786
# ...                ...
# 2019-12-28  293.424591
# 2019-12-29  293.424591
# 2019-12-30  293.424591
# 2019-12-31  294.137421
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
spy = yf.download("SPY",period="max",interval="1wk")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker             SPY         SPY         SPY         SPY        SPY
# Date
# 1993-01-25   24.175381   24.192575   24.072214   24.192575    1003200
# 1993-02-01   24.742796   24.811574   24.192574   24.192574    2234800
# 1993-02-08   24.536465   24.828770   24.502076   24.742798    1159800
# 1993-02-15   23.969038   24.467677   23.556372   24.467677     998700
# 1993-02-22   24.433300   24.450494   23.917467   24.037828    1024300
# ...                ...         ...         ...         ...        ...
# 2026-04-13  710.140015  712.390015  676.580017  677.409973  296541000
# 2026-04-20  713.940002  714.469971  702.280029  708.780029  246362700
# 2026-04-27  720.650024  724.869995  708.369995  713.169983  228403200
# 2026-05-04  737.619995  738.080017  714.989990  720.070007  241124400
# 2026-05-11  739.169983  749.530029  731.830017  736.450012  307587478
#
# [1738 rows x 5 columns]

# %%
apple=yf.download("AAPL",period="max")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
apple
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 1980-12-12    0.098207    0.098634    0.098207    0.098207  469033600
# 1980-12-15    0.093083    0.093510    0.093083    0.093510  175884800
# 1980-12-16    0.086251    0.086678    0.086251    0.086678  105728000
# 1980-12-17    0.088386    0.088813    0.088386    0.088386   86441600
# 1980-12-18    0.090949    0.091376    0.090949    0.090949   73449600
# ...                ...         ...         ...         ...        ...
# 2026-05-11  292.679993  293.880005  290.230011  291.980011   42247300
# 2026-05-12  294.799988  295.269989  292.559998  292.559998   45748100
# 2026-05-13  298.869995  300.920013  293.500000  293.500000   52684300
# 2026-05-14  298.209991  300.450012  295.380005  299.820007   35324900
# 2026-05-15  300.230011  303.200012  296.519989  297.899994   54721100
#
# [11448 rows x 5 columns]

# %%
apple = apple["Close"].squeeze().to_frame(name="Close")

# %%
apple
# Out:
#                  Close
# Date
# 1980-12-12    0.098207
# 1980-12-15    0.093083
# 1980-12-16    0.086251
# 1980-12-17    0.088386
# 1980-12-18    0.090949
# ...                ...
# 2026-05-11  292.679993
# 2026-05-12  294.799988
# 2026-05-13  298.869995
# 2026-05-14  298.209991
# 2026-05-15  300.230011
#
# [11448 rows x 1 columns]

# %%
apple["d_returns"]=np.log(apple.div(apple.shift(1)))

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-12    0.098207        NaN
# 1980-12-15    0.093083  -0.053581
# 1980-12-16    0.086251  -0.076231
# 1980-12-17    0.088386   0.024450
# 1980-12-18    0.090949   0.028580
# ...                ...        ...
# 2026-05-11  292.679993  -0.001263
# 2026-05-12  294.799988   0.007217
# 2026-05-13  298.869995   0.013712
# 2026-05-14  298.209991  -0.002211
# 2026-05-15  300.230011   0.006751
#
# [11448 rows x 2 columns]

# %%
apple.dropna(inplace=True)

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-15    0.093083  -0.053581
# 1980-12-16    0.086251  -0.076231
# 1980-12-17    0.088386   0.024450
# 1980-12-18    0.090949   0.028580
# 1980-12-19    0.096499   0.059239
# ...                ...        ...
# 2026-05-11  292.679993  -0.001263
# 2026-05-12  294.799988   0.007217
# 2026-05-13  298.869995   0.013712
# 2026-05-14  298.209991  -0.002211
# 2026-05-15  300.230011   0.006751
#
# [11447 rows x 2 columns]

# %%
apple.d_returns.sum()
# Out:
# np.float64(8.02522639516485)

# %%
np.exp(apple.d_returns.sum())
# Out:
# np.float64(3057.1133350995046)

# %%
apple["cummreturns"]=apple.d_returns.cumsum().apply(np.exp)

# %%
apple
# Out:
#                  Close  d_returns  cummreturns
# Date
# 1980-12-15    0.093083  -0.053581     0.947829
# 1980-12-16    0.086251  -0.076231     0.878261
# 1980-12-17    0.088386   0.024450     0.899999
# 1980-12-18    0.090949   0.028580     0.926092
# 1980-12-19    0.096499   0.059239     0.982610
# ...                ...        ...          ...
# 2026-05-11  292.679993  -0.001263  2980.234739
# 2026-05-12  294.799988   0.007217  3001.821740
# 2026-05-13  298.869995   0.013712  3043.264877
# 2026-05-14  298.209991  -0.002211  3036.544343
# 2026-05-15  300.230011   0.006751  3057.113335
#
# [11447 rows x 3 columns]

# %%
apple.cummreturns.plot(figsize=(12,8),title="APPLE buy and hold", fontsize=12)
plt.show()

# %%
apple.d_returns.mean()*252
# Out:
# np.float64(0.17667135944627782)

# %%
apple.d_returns.std()*np.sqrt(252)
# Out:
# np.float64(0.4440054600263602)

# %%
#how to cal. drawdowns

# %%
apple["cummax"]=apple.cummreturns.cummax()

# %%
apple
# Out:
#                  Close  d_returns  cummreturns       cummax
# Date
# 1980-12-15    0.093083  -0.053581     0.947829     0.947829
# 1980-12-16    0.086251  -0.076231     0.878261     0.947829
# 1980-12-17    0.088386   0.024450     0.899999     0.947829
# 1980-12-18    0.090949   0.028580     0.926092     0.947829
# 1980-12-19    0.096499   0.059239     0.982610     0.982610
# ...                ...        ...          ...          ...
# 2026-05-11  292.679993  -0.001263  2980.234739  2984.002552
# 2026-05-12  294.799988   0.007217  3001.821740  3001.821740
# 2026-05-13  298.869995   0.013712  3043.264877  3043.264877
# 2026-05-14  298.209991  -0.002211  3036.544343  3043.264877
# 2026-05-15  300.230011   0.006751  3057.113335  3057.113335
#
# [11447 rows x 4 columns]

# %%
apple[["cummreturns","cummax"]].plot(figsize=(12,8),title="APPLE buy and hold = cummax", fontsize=12)
plt.show()

# %%
apple["drawdown"]=apple["cummax"]-apple["cummreturns"]

# %%
apple
# Out:
#                  Close  d_returns  cummreturns       cummax  drawdown
# Date
# 1980-12-15    0.093083  -0.053581     0.947829     0.947829  0.000000
# 1980-12-16    0.086251  -0.076231     0.878261     0.947829  0.069569
# 1980-12-17    0.088386   0.024450     0.899999     0.947829  0.047831
# 1980-12-18    0.090949   0.028580     0.926092     0.947829  0.021737
# 1980-12-19    0.096499   0.059239     0.982610     0.982610  0.000000
# ...                ...        ...          ...          ...       ...
# 2026-05-11  292.679993  -0.001263  2980.234739  2984.002552  3.767812
# 2026-05-12  294.799988   0.007217  3001.821740  3001.821740  0.000000
# 2026-05-13  298.869995   0.013712  3043.264877  3043.264877  0.000000
# 2026-05-14  298.209991  -0.002211  3036.544343  3043.264877  6.720534
# 2026-05-15  300.230011   0.006751  3057.113335  3057.113335  0.000000
#
# [11447 rows x 5 columns]

# %%
apple.drawdown.max()
# Out:
# 874.2941776437269

# %%
apple.drawdown.idxmax()
# Out:
# Timestamp('2025-04-08 00:00:00')

# %%
apple.loc[(apple.index<='2025-04-08')]
# Out:
#                  Close  d_returns  cummreturns       cummax    drawdown
# Date
# 1980-12-15    0.093083  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.086251  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.088386   0.024450     0.899999     0.947829    0.047831
# 1980-12-18    0.090949   0.028580     0.926092     0.947829    0.021737
# 1980-12-19    0.096499   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2025-04-02  222.713226   0.003131  2267.793189  2620.745057  352.951868
# 2025-04-03  202.122025  -0.097013  2058.121820  2620.745057  562.623237
# 2025-04-04  187.389893  -0.075680  1908.110843  2620.745057  712.634214
# 2025-04-07  180.506241  -0.037426  1838.017572  2620.745057  782.727485
# 2025-04-08  171.513748  -0.051102  1746.450879  2620.745057  874.294178
#
# [11170 rows x 5 columns]

# %%
apple["drawdown%"]=(apple["cummax"]-apple["cummreturns"])/apple["cummax"]

# %%
apple
# Out:
#                  Close  d_returns  cummreturns       cummax  drawdown  \
# Date
# 1980-12-15    0.093083  -0.053581     0.947829     0.947829  0.000000
# 1980-12-16    0.086251  -0.076231     0.878261     0.947829  0.069569
# 1980-12-17    0.088386   0.024450     0.899999     0.947829  0.047831
# 1980-12-18    0.090949   0.028580     0.926092     0.947829  0.021737
# 1980-12-19    0.096499   0.059239     0.982610     0.982610  0.000000
# ...                ...        ...          ...          ...       ...
# 2026-05-11  292.679993  -0.001263  2980.234739  2984.002552  3.767812
# 2026-05-12  294.799988   0.007217  3001.821740  3001.821740  0.000000
# 2026-05-13  298.869995   0.013712  3043.264877  3043.264877  0.000000
# 2026-05-14  298.209991  -0.002211  3036.544343  3043.264877  6.720534
# 2026-05-15  300.230011   0.006751  3057.113335  3057.113335  0.000000
#
#             drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# 1980-12-17   0.050463
# 1980-12-18   0.022934
# 1980-12-19   0.000000
# ...               ...
# 2026-05-11   0.001263
# 2026-05-12   0.000000
# 2026-05-13   0.000000
# 2026-05-14   0.002208
# 2026-05-15   0.000000
#
# [11447 rows x 6 columns]

# %%
apple["drawdown%"].max()
# Out:
# 0.8180144800620064

# %%
apple["drawdown%"].idxmax()
# Out:
# Timestamp('2003-04-17 00:00:00')

# %%
apple.loc[(apple.index<='2003-04-17')]
# Out:
#                Close  d_returns  cummreturns     cummax  drawdown  drawdown%
# Date
# 1980-12-15  0.093083  -0.053581     0.947829   0.947829  0.000000   0.000000
# 1980-12-16  0.086251  -0.076231     0.878261   0.947829  0.069569   0.073398
# 1980-12-17  0.088386   0.024450     0.899999   0.947829  0.047831   0.050463
# 1980-12-18  0.090949   0.028580     0.926092   0.947829  0.021737   0.022934
# 1980-12-19  0.096499   0.059239     0.982610   0.982610  0.000000   0.000000
# ...              ...        ...          ...        ...       ...        ...
# 2003-04-11  0.197574  -0.084926     2.011807  10.987790  8.975983   0.816905
# 2003-04-14  0.203262   0.028383     2.069726  10.987790  8.918064   0.811634
# 2003-04-15  0.200418  -0.014091     2.040766  10.987790  8.947024   0.814270
# 2003-04-16  0.198173  -0.011263     2.017909  10.987790  8.969881   0.816350
# 2003-04-17  0.196377  -0.009105     1.999619  10.987790  8.988171   0.818014
#
# [5641 rows x 6 columns]

# %% [markdown]
# ## SMA Strategy

# %%
data=apple.Close.loc[(apple.index>='1991-01-01')]

# %%
data=data.to_frame()

# %%
data
# Out:
#                  Close
# Date
# 1991-01-02    0.307945
# 1991-01-03    0.304406
# 1991-01-04    0.306176
# 1991-01-07    0.306176
# 1991-01-08    0.306176
# ...                ...
# 2026-05-11  292.679993
# 2026-05-12  294.799988
# 2026-05-13  298.869995
# 2026-05-14  298.209991
# 2026-05-15  300.230011
#
# [8907 rows x 1 columns]

# %%
sma_s=50
sma_l=100

# %%
data["sma_s"]=data.Close.rolling(sma_s).mean()
data["sma_l"]=data.Close.rolling(sma_l).mean()

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-01-02    0.307945         NaN         NaN
# 1991-01-03    0.304406         NaN         NaN
# 1991-01-04    0.306176         NaN         NaN
# 1991-01-07    0.306176         NaN         NaN
# 1991-01-08    0.306176         NaN         NaN
# ...                ...         ...         ...
# 2026-05-11  292.679993  263.135558  264.045984
# 2026-05-12  294.799988  263.742032  264.252976
# 2026-05-13  298.869995  264.449287  264.528318
# 2026-05-14  298.209991  265.167920  264.793565
# 2026-05-15  300.230011  265.971512  265.064240
#
# [8907 rows x 3 columns]

# %%
data.plot(figsize=(12,8),title="APPLE - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'APPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc["2016"].plot(figsize=(12,8),title="APPLE - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'APPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
#if sma_s>sma_l we go long, otherwise we go short

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-05-23    0.320940    0.424683    0.407643
# 1991-05-24    0.326274    0.421951    0.407826
# 1991-05-28    0.327163    0.419094    0.408054
# 1991-05-29    0.334276    0.416167    0.408335
# 1991-05-30    0.338721    0.413081    0.408660
# ...                ...         ...         ...
# 2026-05-11  292.679993  263.135558  264.045984
# 2026-05-12  294.799988  263.742032  264.252976
# 2026-05-13  298.869995  264.449287  264.528318
# 2026-05-14  298.209991  265.167920  264.793565
# 2026-05-15  300.230011  265.971512  265.064240
#
# [8808 rows x 3 columns]

# %%
data["position"]=np.where(data["sma_s"]>data["sma_l"],1,-1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 1991-05-23    0.320940    0.424683    0.407643         1
# 1991-05-24    0.326274    0.421951    0.407826         1
# 1991-05-28    0.327163    0.419094    0.408054         1
# 1991-05-29    0.334276    0.416167    0.408335         1
# 1991-05-30    0.338721    0.413081    0.408660         1
# ...                ...         ...         ...       ...
# 2026-05-11  292.679993  263.135558  264.045984        -1
# 2026-05-12  294.799988  263.742032  264.252976        -1
# 2026-05-13  298.869995  264.449287  264.528318        -1
# 2026-05-14  298.209991  265.167920  264.793565         1
# 2026-05-15  300.230011  265.971512  265.064240         1
#
# [8808 rows x 4 columns]

# %%
data.loc["2016",["sma_s","sma_l","position" ]].plot(figsize=(12,8),title="APPLE - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12,secondary_y="position")
# Out:
# <Axes: title={'center': 'APPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data["returnsb&h"]=np.log(data.Close.div(data.Close.shift(1)))

# %%
data["strategy"]=data["returnsb&h"]*data.position.shift(1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  strategy
# Date
# 1991-05-23    0.320940    0.424683    0.407643         1         NaN       NaN
# 1991-05-24    0.326274    0.421951    0.407826         1    0.016483  0.016483
# 1991-05-28    0.327163    0.419094    0.408054         1    0.002721  0.002721
# 1991-05-29    0.334276    0.416167    0.408335         1    0.021507  0.021507
# 1991-05-30    0.338721    0.413081    0.408660         1    0.013209  0.013209
# ...                ...         ...         ...       ...         ...       ...
# 2026-05-11  292.679993  263.135558  264.045984        -1   -0.001263  0.001263
# 2026-05-12  294.799988  263.742032  264.252976        -1    0.007217 -0.007217
# 2026-05-13  298.869995  264.449287  264.528318        -1    0.013712 -0.013712
# 2026-05-14  298.209991  265.167920  264.793565         1   -0.002211  0.002211
# 2026-05-15  300.230011  265.971512  265.064240         1    0.006751  0.006751
#
# [8808 rows x 6 columns]

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h","strategy"]].sum()
# Out:
# returnsb&h    6.841049
# strategy      1.609363
# dtype: float64

# %%
data[["returnsb&h","strategy"]].sum().apply(np.exp)#what 1 $ will be
# Out:
# returnsb&h    935.469745
# strategy        4.999625
# dtype: float64

# %%
data[["returnsb&h","strategy"]].std()*np.sqrt(252)
# Out:
# returnsb&h    0.425886
# strategy      0.426055
# dtype: float64

# %%
data.Close.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Stratergy adjusted with long bias, means only long no short

# %%
data["position2"]=np.where(data["sma_s"]>data["sma_l"],1,0)

# %%
data["strategy2"]=data["returnsb&h"]*data.position2.shift(1)

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  \
# Date
# 1991-05-28    0.327163    0.419094    0.408054         1    0.002721
# 1991-05-29    0.334276    0.416167    0.408335         1    0.021507
# 1991-05-30    0.338721    0.413081    0.408660         1    0.013209
# 1991-05-31    0.334276    0.410154    0.408941         1   -0.013209
# 1991-06-03    0.350278    0.407972    0.409241        -1    0.046761
# ...                ...         ...         ...       ...         ...
# 2026-05-11  292.679993  263.135558  264.045984        -1   -0.001263
# 2026-05-12  294.799988  263.742032  264.252976        -1    0.007217
# 2026-05-13  298.869995  264.449287  264.528318        -1    0.013712
# 2026-05-14  298.209991  265.167920  264.793565         1   -0.002211
# 2026-05-15  300.230011  265.971512  265.064240         1    0.006751
#
#             strategy  position2  strategy2
# Date
# 1991-05-28  0.002721          1   0.002721
# 1991-05-29  0.021507          1   0.021507
# 1991-05-30  0.013209          1   0.013209
# 1991-05-31 -0.013209          1  -0.013209
# 1991-06-03  0.046761          0   0.046761
# ...              ...        ...        ...
# 2026-05-11  0.001263          0  -0.000000
# 2026-05-12 -0.007217          0   0.000000
# 2026-05-13 -0.013712          0   0.000000
# 2026-05-14  0.002211          1  -0.000000
# 2026-05-15  0.006751          1   0.006751
#
# [8806 rows x 8 columns]

# %%
data[["returnsb&h","strategy2"]].sum()
# Out:
# returnsb&h    6.824566
# strategy2     4.208723
# dtype: float64

# %%
data[["returnsb&h","strategy2"]].sum().apply(np.exp)
# Out:
# returnsb&h    920.177028
# strategy2      67.270588
# dtype: float64

# %%
data[["returnsb&h","strategy2"]].std()*np.sqrt(252)
# Out:
# returnsb&h    0.425902
# strategy2     0.328368
# dtype: float64

# %%
##Strategy2 is better than strategy
data[["strategy","strategy2"]].std()*np.sqrt(252)
# Out:
# strategy     0.426070
# strategy2    0.328368
# dtype: float64

# %% [markdown]
# ## challange 2
# ## find the best SMA for top 5 stocks
# ## create a bias theory
# ## compare drawdowns
# ## pick the best 3 stocks for your portfolio

# %% [markdown]
# ## Creating our 1st function

# %%
def test_strategy(stock,start,end,SMA):
    df=yf.download(stock,start=start,end=end)
    data=df[["Close"]].copy()
    data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"]=data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"]=data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)

    data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
    data["strategy"]=data["returns"]*data.position.shift(1)
    data.dropna(inplace=True)
    ret=np.exp(data["strategy"].sum())
    std=data["strategy"].std()*np.sqrt(252)

    return ret,std

# %%
test_strategy("SPY","2000-01-01","2020-01-01",(50,200))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (np.float64(5.952485278925763), np.float64(0.18757933723513498))

# %% [markdown]
# ## creating our 1st class

# %%
class SMABacktester():
    def __init__(self,symbol,SMA_S,SMA_L,start,end):
        self.symbol=symbol
        self.SMA_S=SMA_S
        self.SMA_L=SMA_L
        self.start=start
        self.end=end
        self.results=None
        self.get_data()

    def get_data(self):
        df=yf.download(self.symbol,start=self.start,end=self.end)
        data=df[["Close"]].copy()
        data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"]=data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"]=data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data2=data

        return data

    def test_results(self):
        data=self.data2.copy().dropna()
        data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
        data["strategy"]=data["returns"]*data.position.shift(1)
        data.dropna(inplace=True)
        data["returnsbh"]=data["returns"].cumsum().apply(np.exp)
        data["returnsstrategy"]=data["strategy"].cumsum().apply(np.exp)
        perf=data["returnsstrategy"].iloc[-1]
        outperf=perf-data["returnsbh"].iloc[-1]
        self.results=data
        
        ret=np.exp(data["strategy"].sum())
        std=data["strategy"].std()*np.sqrt(252)
    
        return round(perf,6), round(outperf,6)

    def plot_results(self):
        if self.results is None:
            print("Run the test please")
        else:
            title="{}| SMA_S={} | SMA_L{}".format(self.symbol,self.SMA_S, self.SMA_L)
            self.results[["returnsbh","returnsstrategy"]].plot(title=title, figsize=(12,8))

# %%
tester= SMABacktester("SPY",50,100, "2000-01-01","2020-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (np.float64(3.760713), np.float64(0.430826))

# %%
tester.plot_results()
